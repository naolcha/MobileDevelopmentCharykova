// %% [markdown]
// # Directory

// %%
using System.IO;

string path = @"D:\projekt2";

// %%
Directory.GetFiles(path)
// Out:
// <div class="dni-plaintext"><pre>[ D:\projekt2\file1.txt, D:\projekt2\file2.txt, D:\projekt2\file3.txt, D:\projekt2\file4.txt, D:\projekt2\rgr.py, D:\projekt2\rgr1.xlsx ]</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
var r = Directory.Get(path, "",searchOption: SearchOption.AllDirectories);
foreach (var i in r)
    Console.WriteLine(i);
// Out:
// D:\projekt2\file1.txt
// D:\projekt2\file2.txt
// D:\projekt2\file3.txt
// D:\projekt2\file4.txt
// D:\projekt2\rgr.py
// D:\projekt2\rgr1.xlsx
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\.env
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\postgresql_schema.sql
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\README.md
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\requirements.txt
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\pyvenv.cfg
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\app\main.py
// D:\projekt2\prototype_kadrovoe_agentstvo\archetectureUnv\app\__init__.py
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\Scripts\activate
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\Scripts\activate.bat
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\Scripts\Activate.ps1
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\Scripts\deactivate.bat
// D:\projekt2\prototype_kadrovoe_agentstvo\venv\Scripts\pip.exe
// ...
